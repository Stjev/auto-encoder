# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import Dataset, DataLoader
from glob import glob
import time
import matplotlib.pyplot as plt
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
import datetime

print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# # Create a Dataloader

# %%
IMAGE_W, IMAGE_H = 512, 256

# %%
class ImageDataset(Dataset):
    def __init__(self, train_val_test=0):
        self.train = train_val_test == 0
        self.images = glob(f"./new_ds/{['train', 'val', 'test'][train_val_test]}/*.png")
        self.transform = torchvision.transforms.Compose([
            torchvision.transforms.Normalize(mean=[0.28689554, 0.32513303, 0.28389177], 
                                             std=[0.18696375, 0.19017339, 0.18720214])
        ])
        
    def __len__(self):
        return len(self.images)       
    
    def __getitem__(self, idx):
        img_path = self.images[idx]
        # load and transform image
        img_pil = torchvision.io.read_image(img_path) / 255.
        
        return img_pil

# %%
img_ds = ImageDataset()
test_img = img_ds[4]

print(test_img.mean())
print(test_img.std())
# Out:
# tensor(0.2288)
# tensor(0.1416)

# %%
# print(len(img_ds))

# t1 = time.time()

# for img in img_ds:
#     y = img
    
# print(f"Total time to go through ds: {time.time() - t1:.2f}s")

# %% [markdown]
# ### Ground truth image

# %%
test_img = img_ds[4].unsqueeze(0)

print("min:", test_img.min())
print("max:", test_img.max())
print("mean:", test_img.mean())

plt.figure(figsize=(15, 7))
plt.imshow(test_img.squeeze(0).permute(1, 2, 0))
# Out:
# min: tensor(0.0392)
# max: tensor(0.8078)
# mean: tensor(0.2288)

# %% [markdown]
# ### Image with gaussian noise

# %%
def add_noise(x, std=0.7, device='cuda'):
    return x + torch.randn(x.size(), device=device) * 0.1

# %%
test_img = add_noise(img_ds[4].unsqueeze(0), device='cpu')

print("min:", test_img.min())
print("max:", test_img.max())
print("mean:", test_img.mean())

plt.figure(figsize=(15, 7))
plt.imshow(test_img.squeeze(0).permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: tensor(-0.3408)
# max: tensor(1.1414)
# mean: tensor(0.2289)

# %% [markdown]
# # Create the model

# %%
# CURRENT: https://github.com/milesial/Pytorch-UNet/blob/master/unet/unet_parts.py
# https://medium.com/@tioluwaniaremu/vgg-16-a-simple-implementation-using-pytorch-7850be4d14a1

# State-of-the-art: https://paperswithcode.com/paper/mask-dino-towards-a-unified-transformer-based-1
class Downsample(nn.Module):
    def __init__(self, in_channels, out_channels, skip=True, pool=True):
        super().__init__()
        self.skip = skip
        self.do_pool = pool
        self.conv1 = nn.Conv2d(in_channels=in_channels, 
                              out_channels=out_channels, 
                              kernel_size=3, 
                              padding=1)
        self.batch1 =  nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(in_channels=out_channels, 
                               out_channels=out_channels, 
                               kernel_size=3, 
                               padding=1)
        self.batch2 =  nn.BatchNorm2d(out_channels)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.init_weights()
        
    def init_weights(self):
        torch.nn.init.xavier_normal_(self.conv1.weight, gain=torch.nn.init.calculate_gain(nonlinearity='conv2d'))
        torch.nn.init.xavier_normal_(self.conv2.weight, gain=torch.nn.init.calculate_gain(nonlinearity='conv2d'))
        
    def forward(self, x):
        x = self.conv1(x)
        y = self.batch1(x)
        y = F.relu(y)
        y = self.conv2(y)
        y = self.batch2(y)
        # check if we want a skip connection
        if self.skip:
            y = torch.add(x, y)
        # check if we want pooling
        if self.do_pool:
            y = self.pool(y)
            
        return F.relu(y)
    
class Upsample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels=in_channels, 
                                     out_channels=in_channels, 
                                     kernel_size=2, 
                                     stride=2)
        self.conv = Downsample(in_channels, out_channels, pool=False)
        self.init_weights()
        
    def init_weights(self):
        torch.nn.init.xavier_normal_(self.up.weight, gain=torch.nn.init.calculate_gain(nonlinearity='conv_transpose2d'))
        
    def forward(self, x):
        x = self.up(x)
        x = self.conv(x)
        return x
    
class Encoder(nn.Module):
    def __init__(self, depth, initial_channels=16):
        super().__init__()
        self.ds1 = Downsample(in_channels=3, out_channels=initial_channels)
        pow_2 = int(np.log2(initial_channels))
        self.dss = nn.ModuleList([Downsample(in_channels=min(2**x, 256), 
                                             out_channels=min(2**(x+1), 256), 
                                             pool=(x < pow_2 + depth - 1)) for x in range(pow_2, pow_2 + depth)])
        
    def forward(self, x):
        x = self.ds1(x)
        for ds in self.dss:
            x = ds(x)
        return x
    
class Decoder(nn.Module):
    def __init__(self, depth, initial_channels):
        super().__init__()
        pow_2 = int(np.log2(initial_channels))
        self.uss = nn.ModuleList([Upsample(in_channels=min(2**(x+1), 256), 
                                           out_channels=min(2**x, 256)) for x in reversed(range(pow_2, pow_2 + depth))])
        self.out_conv = nn.Conv2d(initial_channels, 3, kernel_size=1)
        self.init_weights()
        
    def init_weights(self):
        torch.nn.init.xavier_normal_(self.out_conv.weight, gain=torch.nn.init.calculate_gain(nonlinearity='conv2d'))
        
    def forward(self, x):
        for us in self.uss:
            x = us(x)
        x = self.out_conv(x)
        return x
    
class Model(nn.Module):
    def __init__(self, depth, intial_channels):
        super().__init__()
        self.encoder = Encoder(depth=depth, initial_channels=intial_channels)
        self.decoder = Decoder(depth=depth, initial_channels=intial_channels)
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return torch.clamp(x, 0, 1)
        
DEPTH = 5
INTIAL_CHANNELS = 32

m = Model(depth=DEPTH, intial_channels=INTIAL_CHANNELS).cuda()

print(f"Original\t{test_img.shape}")
out = m(test_img.cuda())
print(f"Model out\t{out.shape}")
# Out:
# Original	torch.Size([1, 3, 256, 512])
# Model out	torch.Size([1, 3, 256, 512])

# %%
summary(m, input_size=(3, 256, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 256, 512]             896
#        BatchNorm2d-2         [-1, 32, 256, 512]              64
#             Conv2d-3         [-1, 32, 256, 512]           9,248
#        BatchNorm2d-4         [-1, 32, 256, 512]              64
#          MaxPool2d-5         [-1, 32, 128, 256]               0
#         Downsample-6         [-1, 32, 128, 256]               0
#             Conv2d-7         [-1, 64, 128, 256]          18,496
#        BatchNorm2d-8         [-1, 64, 128, 256]             128
#             Conv2d-9         [-1, 64, 128, 256]          36,928
#       BatchNorm2d-10         [-1, 64, 128, 256]             128
#         MaxPool2d-11          [-1, 64, 64, 128]               0
#        Downsample-12          [-1, 64, 64, 128]               0
#            Conv2d-13         [-1, 128, 64, 128]          73,856
#       BatchNorm2d-14         [-1, 128, 64, 128]             256
#            Conv2d-15         [-1, 128, 64, 128]         147,584
#       BatchNorm2d-16         [-1, 128, 64, 128]             256
#         MaxPool2d-17          [-1, 128, 32, 64]               0
#        Downsample-18          [-1, 128, 32, 64]               0
#            Conv2d-19          [-1, 256, 32, 64]         295,168
#       BatchNorm2d-20          [-1, 256, 32, 64]             512
#            Conv2d-21          [-1, 256, 32, 64]         590,080
#       BatchNorm2d-22          [-1, 256, 32, 64]             512
#         MaxPool2d-23          [-1, 256, 16, 32]               0
#        Downsample-24          [-1, 256, 16, 32]               0
#            Conv2d-25          [-1, 256, 16, 32]         590,080
#       BatchNorm2d-26          [-1, 256, 16, 32]             512
#            Conv2d-27          [-1, 256, 16, 32]         590,080
#       BatchNorm2d-28          [-1, 256, 16, 32]             512
#         MaxPool2d-29           [-1, 256, 8, 16]               0
#        Downsample-30           [-1, 256, 8, 16]               0
#            Conv2d-31           [-1, 256, 8, 16]         590,080
#       BatchNorm2d-32           [-1, 256, 8, 16]             512
#            Conv2d-33           [-1, 256, 8, 16]         590,080
#       BatchNorm2d-34           [-1, 256, 8, 16]             512
#        Downsample-35           [-1, 256, 8, 16]               0
#           Encoder-36           [-1, 256, 8, 16]               0
#   ConvTranspose2d-37          [-1, 256, 16, 32]         262,400
#            Conv2d-38          [-1, 256, 16, 32]         590,080
#       BatchNorm2d-39          [-1, 256, 16, 32]             512
#            Conv2d-40          [-1, 256, 16, 32]         590,080
#       BatchNorm2d-41          [-1, 256, 16, 32]             512
#        Downsample-42          [-1, 256, 16, 32]               0
#          Upsample-43          [-1, 256, 16, 32]               0
#   ConvTranspose2d-44          [-1, 256, 32, 64]         262,400
#            Conv2d-45          [-1, 256, 32, 64]         590,080
#       BatchNorm2d-46          [-1, 256, 32, 64]             512
#            Conv2d-47          [-1, 256, 32, 64]         590,080
#       BatchNorm2d-48          [-1, 256, 32, 64]             512
#        Downsample-49          [-1, 256, 32, 64]               0
#          Upsample-50          [-1, 256, 32, 64]               0
#   ConvTranspose2d-51         [-1, 256, 64, 128]         262,400
#            Conv2d-52         [-1, 128, 64, 128]         295,040
#       BatchNorm2d-53         [-1, 128, 64, 128]             256
#            Conv2d-54         [-1, 128, 64, 128]         147,584
#       BatchNorm2d-55         [-1, 128, 64, 128]             256
#        Downsample-56         [-1, 128, 64, 128]               0
#          Upsample-57         [-1, 128, 64, 128]               0
#   ConvTranspose2d-58        [-1, 128, 128, 256]          65,664
#            Conv2d-59         [-1, 64, 128, 256]          73,792
#       BatchNorm2d-60         [-1, 64, 128, 256]             128
#            Conv2d-61         [-1, 64, 128, 256]          36,928
#       BatchNorm2d-62         [-1, 64, 128, 256]             128
#        Downsample-63         [-1, 64, 128, 256]               0
#          Upsample-64         [-1, 64, 128, 256]               0
#   ConvTranspose2d-65         [-1, 64, 256, 512]          16,448
#            Conv2d-66         [-1, 32, 256, 512]          18,464
#       BatchNorm2d-67         [-1, 32, 256, 512]              64
#            Conv2d-68         [-1, 32, 256, 512]           9,248
#       BatchNorm2d-69         [-1, 32, 256, 512]              64
#        Downsample-70         [-1, 32, 256, 512]               0
#          Upsample-71         [-1, 32, 256, 512]               0
#            Conv2d-72          [-1, 3, 256, 512]              99
#           Decoder-73          [-1, 3, 256, 512]               0
# ================================================================
# Total params: 7,350,275
# Trainable params: 7,350,275
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.50
# Forward/backward pass size (MB): 765.00
# Params size (MB): 28.04
# Estimated Total Size (MB): 794.54
# ----------------------------------------------------------------

# %% [markdown]
# # Training Loop

# %%
BATCH_SIZE = 16
EPOCHS = 1000
LEARNING_RATE = 0.001

# %%
writer = SummaryWriter('runs/DAE' + '_' + datetime.datetime.now().strftime("%d%m-%H%M%S"))

# initialize optimizer 
optim = torch.optim.Adam(m.parameters(), lr=LEARNING_RATE, amsgrad=True)

# dataloader 
dl_train = torch.utils.data.DataLoader(ImageDataset(train_val_test=0), batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# set up validation datasets and validation images
val_ds = ImageDataset(train_val_test=1)
dl_val = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

val_img1, val_img2, val_img3 = val_ds[14], val_ds[307], val_ds[450]

grid = torch.zeros((3, 256 * 2, 512 * 3))
grid[:, :256, 0:512] = val_img1
grid[:, :256, 512:512*2] = val_img2
grid[:, :256, 512*2:512*3] = val_img3

val_set = torch.stack((val_img1, val_img2, val_img3))

# loss function
criterion = torch.nn.MSELoss()

best_loss, patience = 10000, 0

noise_lvl = 0.7

for epoch in range(EPOCHS):
    loss_sum = 0
    t1 = time.time()
    if epoch % 100 == 0 and epoch != 0:
        noise_lvl = max(0, noise_lvl - 0.1)
    m.train()
    for i, batch in enumerate(dl_train):
        # zero the gradient
        optim.zero_grad()
        # put the batch on GPU
        batch = batch.cuda()
        gt_batch = torch.clone(batch)
        # add noise to the input
        batch = add_noise(batch, std=noise_lvl)
        # forward pass
        out = m(batch)
        # calculate loss
        loss = criterion(out, gt_batch)
        # backward pass
        loss.backward()
        # gradient clipping
        nn.utils.clip_grad_value_(m.parameters(), 1)
        # update the weights
        optim.step()
        # add loss to loss sum
        loss_sum += loss.item()
    
    m.eval()
    
    with torch.no_grad():
        # validation and metric logging
        train_loss = loss_sum / len(dl_train)
        val_loss = 0
        
        # calculate validation loss
        for batch in dl_val:
            batch = batch.cuda()
            # forward pass
            out = m(batch)
            # calculate loss
            loss = criterion(out, batch)
            # add loss to loss sum
            val_loss += loss.item()
        
        # average the validation loss
        val_loss /= len(dl_val)
        # create validation images
        val_out = m(val_set.cuda())
    
        grid[:, 256:, 0:512] = torch.clamp(val_out[0], 0, 1)
        grid[:, 256:, 512:512*2] = torch.clamp(val_out[1], 0, 1)
        grid[:, 256:, 512*2:512*3] = torch.clamp(val_out[2], 0, 1)

        writer.add_image('images', grid, epoch)
        writer.add_scalar('Loss/train', train_loss, epoch)
        writer.add_scalar('Val/train', val_loss, epoch)

        if val_loss < best_loss:
            best_loss = val_loss
            patience = 0
        else:
            patience += 1
            
        if patience == 40:
            print("No new best model achieved, stopping here.")
            break
        
        print(f"[{epoch + 1}/{EPOCHS}]\t({time.time() - t1:.2f}s)\tloss: {train_loss:.4f}\tval_loss: {val_loss:.4f}\tpatience: {patience}")
# Out:
# [1/1000]	(75.34s)	loss: 0.0303	val_loss: 0.0149	patience: 0
